# %% [markdown]
# # สมาชิก
# 1. นางสาวหงส์นภาลัย ปิ่นอมรรัตน์ 6209610499
# 2. นางสาวศุภลักษณ์ สุขคุ้ม 6209610804
# 3. นางสาวนภัสสร หทัยเดชะดุษฎี 6209680104

# %% [markdown]
# # Import  package ที่จำเป็น

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'tahoma'

import matplotlib as mpl
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New', size= 10)

# %% [markdown]
# # Data cleansing

# %% [markdown]
# ดาวน์โหลดไฟล์ข้อมูลผู้ป่วยทั้งหมด

# %%
# Mount Drive & Copy Path
# Download file : https://shorturl.asia/Kd5Gx

cs = pd.read_excel('/content/drive/MyDrive/TU/CS385/cs385.xlsx')
cs.head()
# Out:
#          ADM ADM_TIME        D_C D_C_TIME   moo          cwt Expr1006  \
# 0 2018-06-19    16:19 2018-06-20    14:01   7.0  สมุทรปราการ  บางโฉลง
# 1 2020-03-25    09:20 2020-03-26    12:00  11.0  สมุทรปราการ  บางโฉลง
# 2 2018-05-04    12:20 2018-05-05    15:00   7.0  สมุทรปราการ  บางโฉลง
# 3 2018-11-13    10:17 2018-11-16    12:00   7.0  สมุทรปราการ  บางโฉลง
# 4 2018-12-20    10:19 2018-12-21    13:23   7.0  สมุทรปราการ  บางโฉลง
#
#        tam     วันที่       HN  ...  41012500 ค่ารถพยาบาล-IPD  \
# 0  บางโฉลง 2018-06-20       10  ...                       NaN
# 1  บางโฉลง 2020-03-26  1000003  ...                       NaN
# 2  บางโฉลง 2018-05-05  1000022  ...                       NaN
# 3  บางโฉลง 2018-11-16  1000022  ...                       NaN
# 4  บางโฉลง 2018-12-21  1000022  ...                       NaN
#
#   41012900 ค่าโทรศัพท์-IPD  41013000 ค่าเครื่องมือหัตถการ-IPD  \
# 0                      NaN                                NaN
# 1                      NaN                             1400.0
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    41013100 ค่าตรวจสุขภาพ-IPD  41014300 ค่าใส่เฝือก-IPD 41019900 อื่น ๆ -IPD  \
# 0                         NaN                       NaN                 20.0
# 1                         NaN                       NaN                  NaN
# 2                         NaN                       NaN                 20.0
# 3                         NaN                       NaN                120.0
# 4                         NaN                       NaN                 20.0
#
#    41012600 ค่าทำทัตกรรม-IPD  41014501 ค่าบริการผู้ป่วยนอก-IPD  \
# 0                        NaN                              50.0
# 1                        NaN                              50.0
# 2                        NaN                              50.0
# 3                        NaN                              50.0
# 4                        NaN                              50.0
#
#    41010400 ค่าใช้จ่ายห้องคลอด-IPD  41040801 ค่ารักษาพยาบาล(UC)-OPD
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                             30.0
# 3                              NaN                             30.0
# 4                              NaN                             30.0
#
# [5 rows x 47 columns]

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9917 entries, 0 to 9916
# Data columns (total 47 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ADM                                   9917 non-null   datetime64[ns]
#  1   ADM_TIME                              9917 non-null   object
#  2   D_C                                   9917 non-null   datetime64[ns]
#  3   D_C_TIME                              9917 non-null   object
#  4   moo                                   9907 non-null   float64
#  5   cwt                                   9917 non-null   object
#  6   Expr1006                              9917 non-null   object
#  7   tam                                   9917 non-null   object
#  8   วันที่                                9917 non-null   datetime64[ns]
#  9   HN                                    9917 non-null   int64
#  10  TXN                                   9917 non-null   int64
#  11  สิทธิ                                 9917 non-null   object
#  12  รายได้                                9917 non-null   float64
#  13  ส่วนลด                                303 non-null    float64
#  14  รายได้สุทธิ                           9829 non-null   float64
#  15  เลขที่เอกสาร                          7988 non-null   object
#  16  41010100 ค่าห้อง-IPD                  8879 non-null   float64
#  17  41010200 ค่าห้องผ่าตัด-IPD            1063 non-null   float64
#  18  41010300 ค่าใช้จ่ายห้องICU-IPD        460 non-null    float64
#  19  41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD     1377 non-null   float64
#  20  41010600 ค่าใช้จ่ายห้องฉุกเฉิน-IPD    54 non-null     float64
#  21  41010900 ค่าอาหาร-IPD                 8291 non-null   float64
#  22  41011000 ค่าอาหารเหลวทางสายยาง-IPD    216 non-null    float64
#  23  41011100 ค่ายา-IPD                    9108 non-null   float64
#  24  41011200 ค่าอุปกรณ์ในการให้เลือด-IPD  1192 non-null   float64
#  25  41011400 ค่าบริการพยาบาล-IPD          8454 non-null   float64
#  26  41011500 ค่าบริบาล-IPD                628 non-null    float64
#  27  41011600 ค่ารักษาพยาบาล(df)-IPD       9350 non-null   float64
#  28  41011700 ค่าแพทย์ผ่าตัด-IPD           1306 non-null   float64
#  29  41011800 ค่าX-RAY -IPD                4815 non-null   float64
#  30  41011900 ค่าตรวจLAB -IPD              8826 non-null   float64
#  31  41012000 ค่าเวชภัณฑ์การแพทย์ -IPD     9233 non-null   float64
#  32  41012100 ค่าวิสัญญีแพทย์ -IPD         998 non-null    float64
#  33  41013600 ค่าเหมาคลอด-IPD              0 non-null      float64
#  34  41014100 ค่าใบรับรองแพทย์-IPD         85 non-null     float64
#  35  41012200 ค่าตรวจพิเศษต่าง ๆ-IPD       1410 non-null   float64
#  36  41012300 ค่าทำแผล-IPD                 971 non-null    float64
#  37  41012500 ค่ารถพยาบาล-IPD              769 non-null    float64
#  38  41012900 ค่าโทรศัพท์-IPD              6 non-null      float64
#  39  41013000 ค่าเครื่องมือหัตถการ-IPD     3448 non-null   float64
#  40  41013100 ค่าตรวจสุขภาพ-IPD            2 non-null      float64
#  41  41014300 ค่าใส่เฝือก-IPD              52 non-null     float64
#  42  41019900 อื่น ๆ -IPD                  8319 non-null   float64
#  43  41012600 ค่าทำทัตกรรม-IPD             0 non-null      float64
#  44  41014501 ค่าบริการผู้ป่วยนอก-IPD      9241 non-null   float64
#  45  41010400 ค่าใช้จ่ายห้องคลอด-IPD       628 non-null    float64
#  46  41040801 ค่ารักษาพยาบาล(UC)-OPD       2948 non-null   float64
# dtypes: datetime64[ns](3), float64(35), int64(2), object(7)
# memory usage: 3.6+ MB

# %% [markdown]
# # เตรียมข้อมูล

# %% [markdown]
# drop คอลัมน์ที่ไม่ต้องการออก

# %%
cs.drop(['ADM_TIME', 'D_C_TIME', 'moo', 'tam', 'วันที่', 'TXN', 'รายได้', 'เลขที่เอกสาร', '41010300 ค่าใช้จ่ายห้องICU-IPD', 
         '41010600 ค่าใช้จ่ายห้องฉุกเฉิน-IPD', '41010900 ค่าอาหาร-IPD', '41011000 ค่าอาหารเหลวทางสายยาง-IPD', '41011100 ค่ายา-IPD', 
         '41011200 ค่าอุปกรณ์ในการให้เลือด-IPD', '41011400 ค่าบริการพยาบาล-IPD', '41011500 ค่าบริบาล-IPD', '41011600 ค่ารักษาพยาบาล(df)-IPD',
         '41011800 ค่าX-RAY -IPD', '41011900 ค่าตรวจLAB -IPD', '41012000 ค่าเวชภัณฑ์การแพทย์ -IPD', '41012100 ค่าวิสัญญีแพทย์ -IPD', 
         '41013600 ค่าเหมาคลอด-IPD', '41014100 ค่าใบรับรองแพทย์-IPD', '41012200 ค่าตรวจพิเศษต่าง ๆ-IPD', '41012300 ค่าทำแผล-IPD', 
         '41012500 ค่ารถพยาบาล-IPD', '41012900 ค่าโทรศัพท์-IPD', '41013000 ค่าเครื่องมือหัตถการ-IPD', '41013100 ค่าตรวจสุขภาพ-IPD', 
         '41014300 ค่าใส่เฝือก-IPD', '41019900 อื่น ๆ -IPD', '41012600 ค่าทำทัตกรรม-IPD', '41014501 ค่าบริการผู้ป่วยนอก-IPD', 
         '41010400 ค่าใช้จ่ายห้องคลอด-IPD', '41040801 ค่ารักษาพยาบาล(UC)-OPD'], 1, inplace=True)

# %%
cs.head()
# Out:
#          ADM        D_C          cwt Expr1006       HN สิทธิ  ส่วนลด  \
# 0 2018-06-19 2018-06-20  สมุทรปราการ  บางโฉลง       10    A7     NaN
# 1 2020-03-25 2020-03-26  สมุทรปราการ  บางโฉลง  1000003    AA     NaN
# 2 2018-05-04 2018-05-05  สมุทรปราการ  บางโฉลง  1000022   UC1     NaN
# 3 2018-11-13 2018-11-16  สมุทรปราการ  บางโฉลง  1000022   UC1     NaN
# 4 2018-12-20 2018-12-21  สมุทรปราการ  บางโฉลง  1000022   UC1     NaN
#
#    รายได้สุทธิ  41010100 ค่าห้อง-IPD  41010200 ค่าห้องผ่าตัด-IPD  \
# 0       6388.0                 600.0                         NaN
# 1      16555.0                 600.0                      2000.0
# 2       5623.0                 600.0                         NaN
# 3       8680.0                1200.0                         NaN
# 4       4509.0                 600.0                         NaN
#
#    41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD  41011700 ค่าแพทย์ผ่าตัด-IPD
# 0                                NaN                          NaN
# 1                             3150.0                       3000.0
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN

# %% [markdown]
# แทนที่ NaN ด้วย 0

# %%
cs.loc[:,'ส่วนลด':'41011700 ค่าแพทย์ผ่าตัด-IPD'] = cs.loc[:,'ส่วนลด':'41011700 ค่าแพทย์ผ่าตัด-IPD'].fillna(0)

# %%
cs.head()
# Out:
#          ADM        D_C          cwt Expr1006       HN สิทธิ  ส่วนลด  \
# 0 2018-06-19 2018-06-20  สมุทรปราการ  บางโฉลง       10    A7     0.0
# 1 2020-03-25 2020-03-26  สมุทรปราการ  บางโฉลง  1000003    AA     0.0
# 2 2018-05-04 2018-05-05  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0
# 3 2018-11-13 2018-11-16  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0
# 4 2018-12-20 2018-12-21  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0
#
#    รายได้สุทธิ  41010100 ค่าห้อง-IPD  41010200 ค่าห้องผ่าตัด-IPD  \
# 0       6388.0                 600.0                         0.0
# 1      16555.0                 600.0                      2000.0
# 2       5623.0                 600.0                         0.0
# 3       8680.0                1200.0                         0.0
# 4       4509.0                 600.0                         0.0
#
#    41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD  41011700 ค่าแพทย์ผ่าตัด-IPD
# 0                                0.0                          0.0
# 1                             3150.0                       3000.0
# 2                                0.0                          0.0
# 3                                0.0                          0.0
# 4                                0.0                          0.0

# %% [markdown]
# คำนวณจำนวนวันที่พัก

# %%
cs['จำนวนวัน'] = cs['D_C'] - cs['ADM']
cs.drop(['D_C', 'ADM'], 1, inplace=True)

# %%
cs.head()
# Out:
#            cwt Expr1006       HN สิทธิ  ส่วนลด  รายได้สุทธิ  \
# 0  สมุทรปราการ  บางโฉลง       10    A7     0.0       6388.0
# 1  สมุทรปราการ  บางโฉลง  1000003    AA     0.0      16555.0
# 2  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       5623.0
# 3  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       8680.0
# 4  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       4509.0
#
#    41010100 ค่าห้อง-IPD  41010200 ค่าห้องผ่าตัด-IPD  \
# 0                 600.0                         0.0
# 1                 600.0                      2000.0
# 2                 600.0                         0.0
# 3                1200.0                         0.0
# 4                 600.0                         0.0
#
#    41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD  41011700 ค่าแพทย์ผ่าตัด-IPD จำนวนวัน
# 0                                0.0                          0.0   1 days
# 1                             3150.0                       3000.0   1 days
# 2                                0.0                          0.0   1 days
# 3                                0.0                          0.0   3 days
# 4                                0.0                          0.0   1 days

# %% [markdown]
# ตรวจสอบการผ่าตัด

# %%
cs['ผ่าตัด'] = 0

# %%
c1 = cs['41010200 ค่าห้องผ่าตัด-IPD'] != 0
c2 = cs['41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD'] != 0
c3 = cs['41011700 ค่าแพทย์ผ่าตัด-IPD'] != 0

# %%
for i in cs[c1].index:
  cs.iloc[[i],[11]] = 1

for i in cs[c2].index:
  cs.iloc[[i],[11]] = 1

for i in cs[c3].index:
  cs.iloc[[i],[11]] = 1

# %%
cs.drop(['41010200 ค่าห้องผ่าตัด-IPD', '41010500 ค่าใช้จ่ายห้องผ่าตัด-IPD', '41011700 ค่าแพทย์ผ่าตัด-IPD'], 1, inplace=True)
cs.head()
# Out:
#            cwt Expr1006       HN สิทธิ  ส่วนลด  รายได้สุทธิ  \
# 0  สมุทรปราการ  บางโฉลง       10    A7     0.0       6388.0
# 1  สมุทรปราการ  บางโฉลง  1000003    AA     0.0      16555.0
# 2  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       5623.0
# 3  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       8680.0
# 4  สมุทรปราการ  บางโฉลง  1000022   UC1     0.0       4509.0
#
#    41010100 ค่าห้อง-IPD จำนวนวัน  ผ่าตัด
# 0                 600.0   1 days       0
# 1                 600.0   1 days       1
# 2                 600.0   1 days       0
# 3                1200.0   3 days       0
# 4                 600.0   1 days       0

# %% [markdown]
# เปลี่ยนชื่อคอลัมน์

# %%
cs['จังหวัด'] = cs['cwt']
cs['ตำบล'] = cs['Expr1006']
cs.drop(['cwt', 'Expr1006'], 1, inplace=True)
cs.head()
# Out:
#         HN สิทธิ  ส่วนลด  รายได้สุทธิ  41010100 ค่าห้อง-IPD จำนวนวัน  ผ่าตัด  \
# 0       10    A7     0.0       6388.0                 600.0   1 days       0
# 1  1000003    AA     0.0      16555.0                 600.0   1 days       1
# 2  1000022   UC1     0.0       5623.0                 600.0   1 days       0
# 3  1000022   UC1     0.0       8680.0                1200.0   3 days       0
# 4  1000022   UC1     0.0       4509.0                 600.0   1 days       0
#
#        จังหวัด     ตำบล
# 0  สมุทรปราการ  บางโฉลง
# 1  สมุทรปราการ  บางโฉลง
# 2  สมุทรปราการ  บางโฉลง
# 3  สมุทรปราการ  บางโฉลง
# 4  สมุทรปราการ  บางโฉลง

# %% [markdown]
# ดาวน์โหลดไฟล์ข้อมูลผู้ป่วยที่ upgrade ห้องพัก

# %%
# Download file : https://shorturl.asia/VNdic

up = pd.read_excel('/content/drive/MyDrive/TU/CS385/QIPD.xlsx')
up.head()
# Out:
#     HN      TXN       BORN   TYPE        ADM ADM_TIME sex        D_C D_C_TIME  \
# 0   10  1801139 1975-01-21  A7    2018-06-19    16:19   ช 2018-06-20    14:01
# 1  134  2201513 1971-01-03  A7    2022-11-15    16:42   ญ 2022-11-19    15:00
# 2  134  2300240 1971-01-03  A7    2023-02-15    11:52   ญ 2023-02-16    16:00
# 3  134  2201605 1971-01-03  A7    2022-12-04    13:02   ญ 2022-12-10    12:00
# 4  134  2300061 1971-01-03  A7    2023-01-13    16:18   ญ 2023-01-14    18:00
#
#    dxtype   acode  moo              cwt                amp  \
# 0       1  สปบพ04  7.0  สมุทรปราการ      บางพลี
# 1       1  นยปพ03  6.0  นครนายก          ปากพลี
# 2       1  นยปพ03  6.0  นครนายก          ปากพลี
# 3       1  นยปพ03  6.0  นครนายก          ปากพลี
# 4       1  นยปพ03  6.0  นครนายก          ปากพลี
#
#                               tam    icd10  \
# 0  บางโฉลง                         R53
# 1  ปากพลี                          N10
# 2  ปากพลี                          N184
# 3  ปากพลี                          N390
# 4  ปากพลี                          D649
#
#                                                 diag
# 0  R53     Malaise and fatigue                   ...
# 1  N10     Acute tubulo-interstitial nephritis   ...
# 2  N184    Chronic kidney disease, stage 4       ...
# 3  N390    Urinary tract infection, site not spec...
# 4  D649    Anaemia, unspecified                  ...

# %% [markdown]
# drop คอลัมน์ที่ไม่ต้องการออก

# %%
up['เพศ'] = up['sex']
up.drop(['TXN', 'BORN', 'TYPE', 'ADM', 'ADM_TIME', 'sex', 'D_C', 'D_C_TIME', 'dxtype', 'acode', 
         'moo', 'cwt', 'amp', 'tam', 'icd10', 'diag'], 1, inplace=True)

# %%
up.head()
# Out:
#     HN เพศ
# 0   10   ช
# 1  134   ญ
# 2  134   ญ
# 3  134   ญ
# 4  134   ญ
